# %%
from google.colab import userdata
import shutil
from google.colab import files

token = userdata.get('GITHUB_TOKEN')
# !git clone https://{token}@github.com/jaym-01/ContinuousDeD.git tmp
# %pip install -r tmp/requirements.txt

def save(name_):
    folder_path = f"/content/runs/{name_}"
    zip_path = f"/content/{name_}_run.zip"

    shutil.make_archive(
        base_name=zip_path.replace(".zip", ""),
        format="zip",
        root_dir=folder_path
    )

    files.download(zip_path)

# %%
name = "ded_discrete_5bins"
# !python tmp/toy_domain/run.py -agent iqn -action_mode discrete -n_bins 5 -ded -frames 100000 -info {name}
save(name)

# %%
name = "continuous_iqn"
# !python tmp/toy_domain/run.py -action_mode continuous -agent iqn -ded -info continuous_iqn -alpha 0.2 -frames 100000
save(name)
