# %%
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
# !git clone https://{token}@github.com/jaym-01/ContinuousDeD.git tmp
# %pip install -r tmp/requirements.txt

# %%
name = "ded_discrete_5bins"
# !python toy_domain/run.py -agent iqn -action_mode discrete -n_bins 5 -ded -frames 100000 -info {name}

# %%
import shutil
from google.colab import files

folder_path = f"/content/runs/{name}"
zip_path = f"/content/{name}_run.zip"

shutil.make_archive(
    base_name=zip_path.replace(".zip", ""),
    format="zip",
    root_dir=folder_path
)

files.download(zip_path)
