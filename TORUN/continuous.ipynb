# %%
!~/miniforge3/envs/vf/bin/python3 train_ncde.py -c ncde_config_continuous

# %%
!~/miniforge3/envs/vf/bin/python3 encode_data.py -c ncde_config_continuous

# %%
!~/miniforge3/envs/vf/bin/python3 train_rl.py -c iqn_continuous_mimic

# %%
!~/miniforge3/envs/vf/bin/python3 eval_rl.py -c iqn_continuous_mimic
