# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ContinuousDeD/
# Out:
# /content/drive/MyDrive/ContinuousDeD

# %%
import sys, os, pickle
import numpy as np
import torch
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import TwoSlopeNorm

# ── Project root ─────────────────────────────────────────────────────────────
PROJECT_ROOT = os.path.abspath('.')
sys.path.insert(0, os.path.join(PROJECT_ROOT, 'toy_domain'))
sys.path.insert(0, os.path.join(PROJECT_ROOT, 'MedGridHard'))

import med_grid_hard_env  # registers MedGridHard-v0 and MedGridHard-discrete-v0

# ── Discrete run to analyse ───────────────────────────────────────────────────
DISC_RUN_NAME = 'medgridhard_discrete_15bins_50kframes'   # change to match -info flag used during training
DISC_RUN_DIR  = os.path.join(PROJECT_ROOT, 'runs', DISC_RUN_NAME)
N_BINS_DISC   = 15   # must match -n_bins used during training

# ── Hyper-parameters ─────────────────────────────────────────────────────────
N_TAU       = 32
ETA         = 0.25
DEVICE      = 'cuda:0' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
FIXED_STATE = [10.0, 0.0]   # start corner
SIZE        = 10.0

N_KEEP = max(1, int(ETA * N_TAU))
print(f'CVaR: keeping {N_KEEP}/{N_TAU} quantiles (eta={ETA})')
print(f'Fixed state: {FIXED_STATE},  n_bins: {N_BINS_DISC}  ({N_BINS_DISC**2} actions)')
print(f'Device: {DEVICE}')
# Out:
# CVaR: keeping 8/32 quantiles (eta=0.25)
# Fixed state: [10.0, 0.0],  n_bins: 15  (225 actions)
# Device: cuda:0

# %% [markdown]
# ## 1. Ground truth regions
#
# MedGrid is a **10×10** continuous gridworld with:
# * **Red (Death):** 1 quarter-circle at $(0,0)$ and 2 ellipses of semi-axis at $a_1=1.5$, $b_1=2.0$ and $a_2=1.0$, $b_2=2.0$ .
# * **Yellow (Trap):** 1 quarter-circle at $(0,0)$ and 2 ellipses of semi-axis at $a_1=2.0$, $b_1=3.0$ and $a_2=1.5$, $b_2=2.5$ .
# * **Blue (Recovery):** circle at $(7,8)$ of radius $1.5$.
# * **Start:** $(10, 0)$.

# %%
DEATH1_RADIUS = 3.0
TRAP1_RADIUS = 4.0
DEATH2_ELLIPSE_A = 1.0
DEATH2_ELLIPSE_B = 1.5
TRAP2_ELLIPSE_A = 1.5
TRAP2_ELLIPSE_B = 2.5
DEATH3_ELLIPSE_A = 2.0
DEATH3_ELLIPSE_B = 1.0
TRAP3_ELLIPSE_A = 3
TRAP3_ELLIPSE_B = 2
RECOVERY_RADIUS = 0.5
RECOVERY_CENTER = np.array([7.75, 6.75], dtype=np.float32)
DEATH1_CENTER = np.array([1, 1], dtype=np.float32)
DEATH2_CENTER = np.array([9, 5], dtype=np.float32)
DEATH3_CENTER = np.array([5, 6], dtype=np.float32)

def classify_point(x, y):
    dist_death1 = np.sqrt(x**2 + y**2)
    dist_recovery = np.sqrt((x-RECOVERY_CENTER[0])**2 + (y-RECOVERY_CENTER[1])**2)
    if dist_recovery <= RECOVERY_RADIUS:
        return 'recovery'
    if dist_death1 <= DEATH1_RADIUS:
        return 'death'
    if dist_death1 <= TRAP1_RADIUS:
        return 'trap'
    dx, dy = x - DEATH2_CENTER[0], y - DEATH2_CENTER[1]
    if ((dx - dy)**2 / (2 * DEATH2_ELLIPSE_A**2) + (dx + dy)**2 / (2 * DEATH2_ELLIPSE_B**2)) <= 1.0:
        return 'death'
    if ((dx - dy)**2 / (2 * TRAP2_ELLIPSE_A**2) + (dx + dy)**2 / (2 * TRAP2_ELLIPSE_B**2)) <= 1.0:
        return 'trap'
    dx, dy = x - DEATH3_CENTER[0], y - DEATH3_CENTER[1]
    if ((dx - dy)**2 / (2 * DEATH3_ELLIPSE_A**2) + (dx + dy)**2 / (2 * DEATH3_ELLIPSE_B**2)) <= 1.0:
        return 'death'
    if ((dx - dy)**2 / (2 * TRAP3_ELLIPSE_A**2) + (dx + dy)**2 / (2 * TRAP3_ELLIPSE_B**2)) <= 1.0:
        return 'trap'
    return 'neutral'


def build_region_image(resolution=400):
    COLORS = {
        'death':    np.array([231,  76,  60, 200], dtype=np.uint8),
        'trap':     np.array([241, 196,  15, 200], dtype=np.uint8),
        'recovery': np.array([ 52, 152, 219, 200], dtype=np.uint8),
        'neutral':  np.array([255, 255, 255, 255], dtype=np.uint8),
    }
    xs = np.linspace(0, SIZE, resolution)
    ys = np.linspace(0, SIZE, resolution)
    img = np.zeros((resolution, resolution, 4), dtype=np.uint8)
    for j, y in enumerate(ys):
        for i, x in enumerate(xs):
            img[j, i] = COLORS[classify_point(x, y)]
    return img


def plot_ground_truth(ax=None, resolution=400):
    if ax is None:
        fig, ax = plt.subplots(figsize=(6, 6))
    else:
        fig = ax.figure
    ax.imshow(build_region_image(resolution), origin='lower',
              extent=[0, SIZE, 0, SIZE], aspect='equal')
    for i in range(11):
        ax.axhline(i, color='#bdc3c7', lw=0.5, zorder=2)
        ax.axvline(i, color='#bdc3c7', lw=0.5, zorder=2)
    ax.plot(DEATH1_CENTER[0], DEATH1_CENTER[1], 'rx', markersize=10, markeredgewidth=2, zorder=4)
    ax.plot(DEATH2_CENTER[0], DEATH2_CENTER[1], 'rx', markersize=10, markeredgewidth=2, zorder=4)
    ax.plot(DEATH3_CENTER[0], DEATH3_CENTER[1], 'rx', markersize=10, markeredgewidth=2, zorder=4)
    ax.plot(10, 0, 'g*', markersize=16, zorder=5)
    legend_patches = [
        mpatches.Patch(color='#e74c3c', label='Death — r=-1, terminal'),
        mpatches.Patch(color='#f1c40f', label='Trap — r=0, forced step'),
        mpatches.Patch(color='#3498db', label='Recovery — r=+1, terminal'),
        mpatches.Patch(color='white',   label='Neutral — r=0'),
        plt.Line2D([0],[0], marker='*', color='w', markerfacecolor='g', markersize=12, label='Start (10,0)'),
        plt.Line2D([0],[0], marker='x', color='r', markersize=8, markeredgewidth=2, label='Trap targets'),
    ]
    ax.legend(handles=legend_patches, loc='center', fontsize=7,
              framealpha=0.85, bbox_to_anchor=(0.5, 0.5))
    ax.set_xlim(0, SIZE); ax.set_ylim(0, SIZE)
    ax.set_xlabel('x'); ax.set_ylabel('y')
    ax.set_title('MedGridHard — Ground Truth Regions')
    return fig, ax


print('Rasterising region map...')
fig, ax = plot_ground_truth()
plt.tight_layout()
plt.show()
# Out:
# Rasterising region map...

# %% [markdown]
# ## 2. Load discrete agents
#
# Train first if needed:
# ```bash
# cd toy_domain
# ../.venv/bin/python run.py -env MedGridHard -action_mode discrete -n_bins 11 \
#     -agent iqn -ded -frames 50000 -info medgridhard_iqn_discrete
# ```

# %%
# !cd toy_domain/

# %%
# !python toy_domain/run.py -env MedGridHard -action_mode discrete -n_bins 15 \
    -agent iqn -ded -frames 50000 -info medgridhard_discrete_15bins_50kframes
# Out:
# 2026-03-14 17:03:06.069903: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773507786.107957    6900 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773507786.120888    6900 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773507786.154487    6900 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773507786.154522    6900 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773507786.154526    6900 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773507786.154530    6900 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-14 17:03:06.162958: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using  cuda:0
# IQN(
#   (head): Linear(in_features=2, out_features=512, bias=True)
#   (cos_embedding): Linear(in_features=64, out_features=512, bias=True)
#   (ff_1): Linear(in_features=512, out_features=512, bias=True)
#   (ff_2): Linear(in_features=512, out_features=225, bias=True)
# )
# IQN(
#   (head): Linear(in_features=2, out_features=512, bias=True)
#   (cos_embedding): Linear(in_features=64, out_features=512, bias=True)
#   (ff_1): Linear(in_features=512, out_features=512, bias=True)
#   (ff_2): Linear(in_features=512, out_features=225, bias=True)
# )
# IQN(
#   (head): Linear(in_features=2, out_features=512, bias=True)
#   (cos_embedding): Linear(in_features=64, out_features=512, bias=True)
#   (ff_1): Linear(in_features=512, out_features=512, bias=True)
#   (ff_2): Linear(in_features=512, out_features=225, bias=True)
# )
# Episode 100	Frame 298	Average100 Score: -1.00
# Episode 200	Frame 621	Average100 Score: -0.94
# Episode 300	Frame 918	Average100 Score: -0.94
# Episode 333	Frame 999 	Average100 Score: -0.92Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 400	Frame 1195	Average100 Score: -0.94
# Episode 500	Frame 1493	Average100 Score: -0.92
# Episode 600	Frame 1848	Average100 Score: -0.98
# Episode 661	Frame 2000 	Average100 Score: -1.00Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 700	Frame 2110	Average100 Score: -0.98
# Episode 800	Frame 2416	Average100 Score: -0.98
# Episode 900	Frame 2726	Average100 Score: -0.90
# Episode 995	Frame 2997 	Average100 Score: -0.92Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 1000	Frame 3015	Average100 Score: -0.94
# Episode 1100	Frame 3317	Average100 Score: -0.92
# Episode 1200	Frame 3638	Average100 Score: -0.96
# Episode 1300	Frame 3951	Average100 Score: -0.98
# Episode 1315	Frame 3993 	Average100 Score: -0.98Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 1400	Frame 4242	Average100 Score: -0.94
# Episode 1500	Frame 4550	Average100 Score: -0.96
# Episode 1600	Frame 4877	Average100 Score: -0.94
# Episode 1643	Frame 5000 	Average100 Score: -0.96Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 1700	Frame 5166	Average100 Score: -0.98
# Episode 1800	Frame 5494	Average100 Score: -0.98
# Episode 1900	Frame 5811	Average100 Score: -0.98
# Episode 1956	Frame 6000 	Average100 Score: -1.00Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 2000	Frame 6149	Average100 Score: -1.00
# Episode 2100	Frame 6463	Average100 Score: -0.94
# Episode 2200	Frame 6765	Average100 Score: -0.96
# Episode 2277	Frame 7000 	Average100 Score: -0.94Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 2300	Frame 7050	Average100 Score: -0.90
# Episode 2400	Frame 7376	Average100 Score: -0.92
# Episode 2500	Frame 7676	Average100 Score: -0.92
# Episode 2600	Frame 7963	Average100 Score: -0.98
# Episode 2613	Frame 7997 	Average100 Score: -0.98Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 2700	Frame 8272	Average100 Score: -0.96
# Episode 2800	Frame 8614	Average100 Score: -0.96
# Episode 2900	Frame 8924	Average100 Score: -0.96
# Episode 2926	Frame 9000 	Average100 Score: -0.96Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 3000	Frame 9220	Average100 Score: -0.98
# Episode 3100	Frame 9542	Average100 Score: -0.94
# Episode 3200	Frame 9851	Average100 Score: -1.00
# Episode 3249	Frame 9998 	Average100 Score: -1.00Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 3300	Frame 10146	Average100 Score: -0.96
# Episode 3400	Frame 10485	Average100 Score: -0.98
# Episode 3500	Frame 10763	Average100 Score: -0.96
# Episode 3573	Frame 10998 	Average100 Score: -0.96Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 3600	Frame 11080	Average100 Score: -0.96
# Episode 3700	Frame 11391	Average100 Score: -0.94
# Episode 3800	Frame 11722	Average100 Score: -0.96
# Episode 3900	Frame 11993	Average100 Score: -1.00
# Episode 3902	Frame 12000 	Average100 Score: -1.00Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 4000	Frame 12303	Average100 Score: -0.96
# Episode 4100	Frame 12619	Average100 Score: -0.98
# Episode 4200	Frame 12947	Average100 Score: -0.94
# Episode 4216	Frame 12997 	Average100 Score: -0.94Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 4300	Frame 13264	Average100 Score: -0.98
# Episode 4400	Frame 13570	Average100 Score: -0.90
# Episode 4500	Frame 13880	Average100 Score: -0.94
# Episode 4534	Frame 13997 	Average100 Score: -0.94Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 4600	Frame 14211	Average100 Score: -0.98
# Episode 4700	Frame 14559	Average100 Score: -0.92
# Episode 4800	Frame 14854	Average100 Score: -0.92
# Episode 4849	Frame 14996 	Average100 Score: -0.92Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 4900	Frame 15155	Average100 Score: -0.90
# Episode 5000	Frame 15463	Average100 Score: -0.92
# Episode 5100	Frame 15775	Average100 Score: -0.96
# Episode 5178	Frame 15996 	Average100 Score: -0.96Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 5200	Frame 16056	Average100 Score: -0.98
# Episode 5300	Frame 16387	Average100 Score: -0.96
# Episode 5400	Frame 16695	Average100 Score: -1.00
# Episode 5500	Frame 17000	Average100 Score: -0.88
# Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 5600	Frame 17295	Average100 Score: -0.90
# Episode 5700	Frame 17587	Average100 Score: -0.88
# Episode 5800	Frame 17884	Average100 Score: -0.96
# Episode 5838	Frame 18000 	Average100 Score: -0.94Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 5900	Frame 18180	Average100 Score: -0.90
# Episode 6000	Frame 18478	Average100 Score: -0.92
# Episode 6100	Frame 18785	Average100 Score: -0.96
# Episode 6171	Frame 18999 	Average100 Score: -0.94Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 6200	Frame 19098	Average100 Score: -0.92
# Episode 6300	Frame 19426	Average100 Score: -0.90
# Episode 6400	Frame 19703	Average100 Score: -0.86
# Episode 6498	Frame 19998 	Average100 Score: -0.90Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 6500	Frame 20008	Average100 Score: -0.90
# Episode 6600	Frame 20291	Average100 Score: -0.98
# Episode 6700	Frame 20593	Average100 Score: -0.96
# Episode 6800	Frame 20902	Average100 Score: -0.94
# Episode 6836	Frame 21000 	Average100 Score: -0.92Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 6900	Frame 21203	Average100 Score: -0.88
# Episode 7000	Frame 21556	Average100 Score: -0.94
# Episode 7100	Frame 21857	Average100 Score: -0.96
# Episode 7150	Frame 21998 	Average100 Score: -0.92Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 7200	Frame 22174	Average100 Score: -0.90
# Episode 7300	Frame 22502	Average100 Score: -1.00
# Episode 7400	Frame 22777	Average100 Score: -0.94
# Episode 7471	Frame 22997 	Average100 Score: -0.96Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 7500	Frame 23098	Average100 Score: -0.98
# Episode 7600	Frame 23404	Average100 Score: -0.96
# Episode 7700	Frame 23692	Average100 Score: -0.96
# Episode 7790	Frame 23999 	Average100 Score: -0.92Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 7800	Frame 24032	Average100 Score: -0.92
# Episode 7900	Frame 24337	Average100 Score: -0.90
# Episode 8000	Frame 24632	Average100 Score: -0.90
# Episode 8100	Frame 24920	Average100 Score: -0.90
# Episode 8129	Frame 24997 	Average100 Score: -1.00Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 8200	Frame 25252	Average100 Score: -0.96
# Episode 8300	Frame 25551	Average100 Score: -0.92
# Episode 8400	Frame 25830	Average100 Score: -0.90
# Episode 8452	Frame 25998 	Average100 Score: -0.90Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 8500	Frame 26150	Average100 Score: -0.92
# Episode 8600	Frame 26439	Average100 Score: -0.94
# Episode 8700	Frame 26776	Average100 Score: -1.00
# Episode 8768	Frame 27000 	Average100 Score: -0.96Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 8800	Frame 27090	Average100 Score: -0.92
# Episode 8900	Frame 27446	Average100 Score: -0.86
# Episode 9000	Frame 27775	Average100 Score: -0.94
# Episode 9073	Frame 27996 	Average100 Score: -0.90Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 9100	Frame 28073	Average100 Score: -0.94
# Episode 9200	Frame 28442	Average100 Score: -0.92
# Episode 9300	Frame 28759	Average100 Score: -0.96
# Episode 9387	Frame 29000 	Average100 Score: -0.88Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 9400	Frame 29044	Average100 Score: -0.88
# Episode 9500	Frame 29358	Average100 Score: -0.94
# Episode 9600	Frame 29649	Average100 Score: -0.86
# Episode 9700	Frame 29983	Average100 Score: -0.92
# Episode 9706	Frame 30000 	Average100 Score: -0.90Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 9800	Frame 30274	Average100 Score: -0.88
# Episode 9900	Frame 30587	Average100 Score: -0.90
# Episode 10000	Frame 30895	Average100 Score: -0.88
# Episode 10036	Frame 31000 	Average100 Score: -0.88Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 10100	Frame 31219	Average100 Score: -0.94
# Episode 10200	Frame 31520	Average100 Score: -0.92
# Episode 10300	Frame 31860	Average100 Score: -0.96
# Episode 10354	Frame 31999 	Average100 Score: -1.00Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 10400	Frame 32156	Average100 Score: -0.98
# Episode 10500	Frame 32472	Average100 Score: -0.98
# Episode 10600	Frame 32752	Average100 Score: -0.88
# Episode 10688	Frame 33000 	Average100 Score: -0.78Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 10700	Frame 33041	Average100 Score: -0.80
# Episode 10800	Frame 33398	Average100 Score: -0.94
# Episode 10900	Frame 33676	Average100 Score: -0.88
# Episode 11000	Frame 33994	Average100 Score: -0.94
# Episode 11002	Frame 33999 	Average100 Score: -0.94Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 11100	Frame 34323	Average100 Score: -0.94
# Episode 11200	Frame 34656	Average100 Score: -0.94
# Episode 11300	Frame 34928	Average100 Score: -0.86
# Episode 11325	Frame 35000 	Average100 Score: -0.86Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 11400	Frame 35250	Average100 Score: -0.84
# Episode 11500	Frame 35586	Average100 Score: -0.90
# Episode 11600	Frame 35894	Average100 Score: -0.94
# Episode 11633	Frame 36000 	Average100 Score: -0.92Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 11700	Frame 36198	Average100 Score: -0.92
# Episode 11800	Frame 36582	Average100 Score: -0.90
# Episode 11900	Frame 36905	Average100 Score: -0.96
# Episode 11934	Frame 37000 	Average100 Score: -0.96Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 12000	Frame 37226	Average100 Score: -0.90
# Episode 12100	Frame 37567	Average100 Score: -0.88
# Episode 12200	Frame 37868	Average100 Score: -0.94
# Episode 12243	Frame 38000 	Average100 Score: -0.88Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 12300	Frame 38160	Average100 Score: -0.86
# Episode 12400	Frame 38483	Average100 Score: -0.92
# Episode 12500	Frame 38818	Average100 Score: -0.94
# Episode 12553	Frame 38998 	Average100 Score: -0.92Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 12600	Frame 39150	Average100 Score: -0.94
# Episode 12700	Frame 39469	Average100 Score: -0.94
# Episode 12800	Frame 39818	Average100 Score: -0.98
# Episode 12871	Frame 40000 	Average100 Score: -0.96Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 12900	Frame 40094	Average100 Score: -0.96
# Episode 13000	Frame 40383	Average100 Score: -0.90
# Episode 13100	Frame 40676	Average100 Score: -0.96
# Episode 13200	Frame 40966	Average100 Score: -0.96
# Episode 13210	Frame 40995 	Average100 Score: -0.96Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 13300	Frame 41308	Average100 Score: -0.94
# Episode 13400	Frame 41622	Average100 Score: -0.92
# Episode 13500	Frame 41946	Average100 Score: -0.92
# Episode 13516	Frame 41999 	Average100 Score: -0.90Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 13600	Frame 42268	Average100 Score: -0.90
# Episode 13700	Frame 42585	Average100 Score: -0.90
# Episode 13800	Frame 42915	Average100 Score: -0.96
# Episode 13832	Frame 42996 	Average100 Score: -0.94Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 13900	Frame 43210	Average100 Score: -0.92
# Episode 14000	Frame 43525	Average100 Score: -0.94
# Episode 14100	Frame 43825	Average100 Score: -0.96
# Episode 14151	Frame 44000 	Average100 Score: -0.98Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 14200	Frame 44180	Average100 Score: -1.00
# Episode 14300	Frame 44502	Average100 Score: -0.94
# Episode 14400	Frame 44821	Average100 Score: -0.94
# Episode 14447	Frame 44999 	Average100 Score: -0.90Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 14500	Frame 45171	Average100 Score: -0.90
# Episode 14600	Frame 45480	Average100 Score: -0.94
# Episode 14700	Frame 45819	Average100 Score: -0.94
# Episode 14754	Frame 45994 	Average100 Score: -0.96Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 14800	Frame 46149	Average100 Score: -0.96
# Episode 14900	Frame 46432	Average100 Score: -0.88
# Episode 15000	Frame 46736	Average100 Score: -0.90
# Episode 15072	Frame 47000 	Average100 Score: -0.90Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 15100	Frame 47083	Average100 Score: -0.92
# Episode 15200	Frame 47388	Average100 Score: -0.92
# Episode 15300	Frame 47713	Average100 Score: -0.88
# Episode 15396	Frame 48000 	Average100 Score: -0.92Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 15400	Frame 48014	Average100 Score: -0.94
# Episode 15500	Frame 48360	Average100 Score: -0.86
# Episode 15600	Frame 48682	Average100 Score: -0.96
# Episode 15700	Frame 48975	Average100 Score: -0.90
# Episode 15707	Frame 48997 	Average100 Score: -0.90Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Episode 15800	Frame 49285	Average100 Score: -0.88
# Episode 15900	Frame 49590	Average100 Score: -0.90
# Episode 16000	Frame 49897	Average100 Score: -0.90
# Episode 16026	Frame 50000 	Average100 Score: -0.90Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes
# Training time: 15.79min
# Saved agent(s) to runs/medgridhard_discrete_15bins_50kframes

# %%
disc_agent, disc_qd, disc_qr = None, None, None
try:
    with open(os.path.join(DISC_RUN_DIR, f'{DISC_RUN_NAME}_agent.pkl'), 'rb') as f:
        disc_agent = pickle.load(f)
    print('Loaded discrete main agent')
    with open(os.path.join(DISC_RUN_DIR, f'{DISC_RUN_NAME}_Qd.pkl'), 'rb') as f:
        disc_qd = pickle.load(f)
    with open(os.path.join(DISC_RUN_DIR, f'{DISC_RUN_NAME}_Qr.pkl'), 'rb') as f:
        disc_qr = pickle.load(f)
    print('Loaded discrete Qd and Qr networks')
except FileNotFoundError as e:
    print(f'Agents not found ({e}) — train first with the command above.')
# Out:
# Loaded discrete main agent
# Loaded discrete Qd and Qr networks

# %% [markdown]
# ## 3. Discrete agent — CVaR Q-value heatmaps over action grid at state (10, 0)
#
# The discrete IQN outputs quantiles for **all actions simultaneously**: `forward(state, n_tau) -> (1, n_tau, n_actions)`.
# We compute the lower CVaR at level η for each action, then reshape the `n_bins²` values back into the `(n_bins, n_bins)` spatial grid to visualise them in the 10×10 coordinate frame.

# %%
def compute_discrete_action_heatmap(disc_ded_agent, state=FIXED_STATE,
                                     n_bins=N_BINS_DISC, n_tau=N_TAU, eta=ETA, device=DEVICE):
    """
    Compute CVaR Q-values for all n_bins^2 discrete actions at a fixed state.

    The discrete IQN forward pass returns (1, n_tau, n_actions), giving all
    action quantiles in one shot.

    Returns
    -------
    heatmap : (n_bins, n_bins) float32 — row=x bin, col=y bin
    bins    : 1-D array of grid coordinates (same for both axes)
    """
    n_keep = max(1, int(eta * n_tau))
    network = disc_ded_agent.qnetwork_local.to(device)
    network.eval()

    s = torch.tensor([state], dtype=torch.float32).to(device)  # (1, 2)

    with torch.no_grad():
        quantiles, _ = network.forward(s, num_tau=n_tau)
        # quantiles: (1, n_tau, n_actions)

    q = quantiles.squeeze(0).cpu().numpy()     # (n_tau, n_actions)
    q_sorted = np.sort(q, axis=0)              # ascending along quantile axis
    cvar = q_sorted[:n_keep, :].mean(axis=0)   # (n_actions,)

    # action i encodes (bins[i//n_bins], bins[i%n_bins])
    heatmap = cvar.reshape(n_bins, n_bins)
    bins = np.linspace(0.0, SIZE, n_bins, dtype=np.float32)
    return heatmap, bins


def plot_discrete_action_heatmap(heatmap, bins, title, ax=None):
    """
    Plot the discrete CVaR heatmap in the 10x10 MedGrid coordinate frame.
    x-axis = action x target, y-axis = action y target.
    """
    if ax is None:
        fig, ax = plt.subplots(figsize=(5, 4))
    else:
        fig = ax.figure

    # heatmap[i,j] = CVaR for action (bins[i], bins[j])
    # transpose: rows->y, cols->x for imshow origin='lower'
    display = heatmap.T

    norm = TwoSlopeNorm(vmin=display.min(), vcenter=0, vmax=max(display.max(), 1e-6))
    im = ax.imshow(
        display,
        origin='lower',
        extent=[bins[0], bins[-1], bins[0], bins[-1]],
        cmap='RdBu',
        norm=norm,
        aspect='equal',
        interpolation='nearest',
    )
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04, label='CVaR Q')

    for b in bins:
        ax.axvline(b, color='k', lw=0.4, alpha=0.4)
        ax.axhline(b, color='k', lw=0.4, alpha=0.4)

    ax.set_xlim(0, SIZE); ax.set_ylim(0, SIZE)
    ax.set_xlabel('action x'); ax.set_ylabel('action y')
    ax.set_title(title)
    return fig, ax

# %% [markdown]
# ### 3a. Q_d (danger network) — discrete action grid at state (10, 0)
# Actions leading toward danger should be **red (≈ −1)**; safe actions **white/blue**.

# %%
assert disc_qd is not None, 'disc_qd not loaded — train first with the command above'

print(f'Computing discrete Qd heatmap at state {FIXED_STATE}...')
disc_heatmap_d, disc_bins = compute_discrete_action_heatmap(disc_qd)
print(f'  range: [{disc_heatmap_d.min():.3f}, {disc_heatmap_d.max():.3f}]')

fig, ax = plot_discrete_action_heatmap(disc_heatmap_d, disc_bins,
                                        title=f'$Q_d$ CVaR (η={ETA}) @ {FIXED_STATE}  [discrete]')
plt.tight_layout()
plt.show()
# Out:
# Computing discrete Qd heatmap at state [10.0, 0.0]...
#   range: [-1.073, 0.016]

# %% [markdown]
# ### 3b. Q_r (recovery network) — discrete action grid at state (10, 0)
# Actions leading toward recovery should be **blue (≈ +1)**; others **white/red**.

# %%
assert disc_qr is not None, 'disc_qr not loaded — train first with the command above'

print(f'Computing discrete Qr heatmap at state {FIXED_STATE}...')
disc_heatmap_r, _ = compute_discrete_action_heatmap(disc_qr)
print(f'  range: [{disc_heatmap_r.min():.3f}, {disc_heatmap_r.max():.3f}]')

fig, ax = plot_discrete_action_heatmap(disc_heatmap_r, disc_bins,
                                        title=f'$Q_r$ CVaR (η={ETA}) @ {FIXED_STATE}  [discrete]')
plt.tight_layout()
plt.show()
# Out:
# Computing discrete Qr heatmap at state [10.0, 0.0]...
#   range: [-0.029, 0.990]

# %% [markdown]
# ## 4. Side-by-side summary — discrete agent

# %%
if disc_qd is not None and disc_qr is not None:
    fig, axes = plt.subplots(1, 3, figsize=(16, 5))

    plot_ground_truth(ax=axes[0], resolution=200)
    plot_discrete_action_heatmap(disc_heatmap_d, disc_bins,
                                  title=f'$Q_d$  CVaR (η={ETA}) @ {FIXED_STATE}', ax=axes[1])
    plot_discrete_action_heatmap(disc_heatmap_r, disc_bins,
                                  title=f'$Q_r$  CVaR (η={ETA}) @ {FIXED_STATE}', ax=axes[2])

    fig.suptitle(
        f'MedGrid — {DISC_RUN_NAME}  |  discrete action grid ({N_BINS_DISC}x{N_BINS_DISC}) at state {FIXED_STATE}',
        fontsize=13)
    plt.tight_layout()
    out_path = os.path.join(DISC_RUN_DIR, 'medgrid_disc_ded_action_heatmaps.png')
    plt.savefig(out_path, dpi=150, bbox_inches='tight')
    plt.show()
    print('Saved to', out_path)
else:
    print('Skipped — no trained agents loaded.')
# Out:
# Saved to /content/drive/MyDrive/ContinuousDeD/runs/medgridhard_discrete_15bins_50kframes/medgrid_disc_ded_action_heatmaps.png

# %% [markdown]
# ## 5. Sweep across states of interest
#
# Evaluate the discrete CVaR heatmaps at multiple states to see how the Q-value landscape shifts depending on where the agent currently is.

# %%
EVAL_STATES = [
    [10.0,  0.0],   # start corner
    [ 5.0,  5.0],   # centre (recovery zone)
    [ 7.0,  3.0],   # neutral, mid-right
    [ 4.0,  0.5],   # inside BL trap band
]

if disc_qd is not None and disc_qr is not None:
    fig, axes = plt.subplots(len(EVAL_STATES), 3,
                             figsize=(16, 5 * len(EVAL_STATES)))

    for row, state in enumerate(EVAL_STATES):
        hm_d, bins = compute_discrete_action_heatmap(disc_qd, state=state)
        hm_r, _    = compute_discrete_action_heatmap(disc_qr, state=state)

        plot_ground_truth(ax=axes[row, 0], resolution=200)
        axes[row, 0].plot(state[0], state[1], 'ms', markersize=10, zorder=6,
                          label=f'Query {state}')
        axes[row, 0].legend(loc='upper right', fontsize=6)

        plot_discrete_action_heatmap(hm_d, bins,
                                      title=f'$Q_d$ CVaR (η={ETA}) @ {state}',
                                      ax=axes[row, 1])
        plot_discrete_action_heatmap(hm_r, bins,
                                      title=f'$Q_r$ CVaR (η={ETA}) @ {state}',
                                      ax=axes[row, 2])

    fig.suptitle(
        f'MedGrid — {DISC_RUN_NAME}  |  discrete ({N_BINS_DISC}x{N_BINS_DISC}) across states',
        fontsize=13)
    plt.tight_layout()
    out_path = os.path.join(DISC_RUN_DIR, 'medgrid_disc_ded_multi_state_heatmaps.png')
    plt.savefig(out_path, dpi=150, bbox_inches='tight')
    plt.show()
    print('Saved to', out_path)
else:
    print('Skipped — no trained agents loaded.')
# Out:
# Saved to /content/drive/MyDrive/ContinuousDeD/runs/medgridhard_discrete_15bins_50kframes/medgrid_disc_ded_multi_state_heatmaps.png

# %% [markdown]
# ## 6. Region Detection Metrics — Precision, Recall, F1, Confusion Matrix, Boundary IoU
#
# The discrete agent predicts Q-values for all `n_bins²` actions at once. We treat each action bin center as a candidate **target position** (queried from the start state) and compare the agent's prediction against the ground-truth region label.
#
# **Prediction rule (winner-takes-all):**
# - If `CVaR(Q_d) < 0` and `|CVaR(Q_d)| ≥ CVaR(Q_r)` → **danger**
# - Else if `CVaR(Q_r) > 0` → **recovery**
# - Else → **safe**
#
# GT is collapsed to 3 classes: `danger = {death, trap}`, `recovery`, `safe = {neutral}`.
#
# For more robust metrics and Boundary IoU, the agent predictions are upsampled to a **200×200 dense grid** via nearest-neighbour.

# %%
from sklearn.metrics import (precision_recall_fscore_support,
                               confusion_matrix, ConfusionMatrixDisplay)
from scipy.ndimage import binary_erosion, binary_dilation

assert disc_qd is not None and disc_qr is not None, "Need loaded agents — run cell 2 first"

DENSE_RES = 200   # pixels per axis for upsampled evaluation
CLASSES   = ['dead_end', 'not_dead_end']

# ── 1. CVaR predictions from the start state ─────────────────────────────────
hm_d_eval, bins_eval = compute_discrete_action_heatmap(disc_qd, state=FIXED_STATE)
hm_r_eval, _         = compute_discrete_action_heatmap(disc_qr, state=FIXED_STATE)
n_bins = len(bins_eval)

# ── 2. Classify each bin: Q_d < 0 → dead_end, else → not_dead_end ─────────────
pred_grid = np.full((n_bins, n_bins), 'not_dead_end', dtype=object)
for i in range(n_bins):
    for j in range(n_bins):
        if hm_d_eval[i, j] < 0:
            pred_grid[i, j] = 'dead_end'

# ── 3. Build dense 200×200 maps (nearest-neighbour upsampling) ────────────────
xs_dense = np.linspace(0, SIZE, DENSE_RES)
ys_dense = np.linspace(0, SIZE, DENSE_RES)

gt_dense   = np.empty((DENSE_RES, DENSE_RES), dtype=object)
pred_dense = np.empty((DENSE_RES, DENSE_RES), dtype=object)

for j, y in enumerate(ys_dense):
    for i, x in enumerate(xs_dense):
        raw = classify_point(x, y)
        gt_dense[j, i] = 'dead_end' if raw in ('death', 'trap') else 'not_dead_end'

        bi = int(np.argmin(np.abs(bins_eval - x)))
        bj = int(np.argmin(np.abs(bins_eval - y)))
        pred_dense[j, i] = pred_grid[bi, bj]

gt_flat   = gt_dense.ravel()
pred_flat = pred_dense.ravel()

print(f"Dense grid: {DENSE_RES}×{DENSE_RES} = {DENSE_RES**2} pixels\n")
print(f"{'Class':<14} {'GT count':>10} {'Pred count':>12}")
print("─" * 38)
for c in CLASSES:
    print(f"{c:<14} {(gt_flat == c).sum():>10} {(pred_flat == c).sum():>12}")
# Out:
# Dense grid: 200×200 = 40000 pixels
#
# Class            GT count   Pred count
# ──────────────────────────────────────
# dead_end            16040        38662
# not_dead_end        23960         1338

# %%
# ── Confusion Matrix ──────────────────────────────────────────────────────────
cm = confusion_matrix(gt_flat, pred_flat, labels=CLASSES)

fig, ax = plt.subplots(figsize=(6, 5))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=CLASSES)
disp.plot(ax=ax, colorbar=True, cmap='Blues', values_format='d')
ax.set_title(
    f'Confusion Matrix — {DISC_RUN_NAME}\n'
    f'(dense 200×200 grid, upsampled from {n_bins}×{n_bins} bins, source state {FIXED_STATE})',
    fontsize=10)
plt.tight_layout()
out_path = os.path.join(DISC_RUN_DIR, 'medgrid_disc_confusion_matrix.png')
plt.savefig(out_path, dpi=150, bbox_inches='tight')
plt.show()
print('Saved to', out_path)
# Out:
# Saved to /content/drive/MyDrive/ContinuousDeD/runs/medgridhard_discrete_15bins_50kframes/medgrid_disc_confusion_matrix.png

# %%
# ── Precision / Recall / F1 ───────────────────────────────────────────────────
prec, rec, f1, support = precision_recall_fscore_support(
    gt_flat, pred_flat, labels=CLASSES, zero_division=0
)

print(f"{'Class':<12} {'Precision':>10} {'Recall':>10} {'F1':>10} {'Support':>10}")
print("─" * 56)
for i, c in enumerate(CLASSES):
    print(f"{c:<12} {prec[i]:>10.3f} {rec[i]:>10.3f} {f1[i]:>10.3f} {support[i]:>10,}")
print("─" * 56)
macro_p  = prec.mean()
macro_r  = rec.mean()
macro_f1 = f1.mean()
print(f"{'Macro avg':<12} {macro_p:>10.3f} {macro_r:>10.3f} {macro_f1:>10.3f}")

# Bar chart
fig, axes = plt.subplots(1, 3, figsize=(12, 4), sharey=True)
metrics = [prec, rec, f1]
titles  = ['Precision', 'Recall', 'F1 Score']
colors  = ['#e74c3c', '#3498db', '#2ecc71']

for ax, vals, title, col in zip(axes, metrics, titles, colors):
    bars = ax.bar(CLASSES, vals, color=col, alpha=0.8, edgecolor='black', linewidth=0.7)
    ax.set_ylim(0, 1.05)
    ax.set_title(title, fontsize=12, fontweight='bold')
    ax.set_ylabel('Score' if ax is axes[0] else '')
    ax.axhline(macro_p if title == 'Precision' else
               macro_r if title == 'Recall' else macro_f1,
               color='k', linestyle='--', linewidth=1, label='Macro avg')
    ax.legend(fontsize=8)
    for bar, val in zip(bars, vals):
        ax.text(bar.get_x() + bar.get_width() / 2, val + 0.02,
                f'{val:.2f}', ha='center', va='bottom', fontsize=9)

fig.suptitle(f'Per-class Metrics — {DISC_RUN_NAME}  ({n_bins}×{n_bins} bins)', fontsize=12)
plt.tight_layout()
out_path = os.path.join(DISC_RUN_DIR, 'medgrid_disc_prec_rec_f1.png')
plt.savefig(out_path, dpi=150, bbox_inches='tight')
plt.show()
print('Saved to', out_path)
# Out:
# Class         Precision     Recall         F1    Support
# ────────────────────────────────────────────────────────
# dead_end          0.415      1.000      0.586     16,040
# not_dead_end      1.000      0.056      0.106     23,960
# ────────────────────────────────────────────────────────
# Macro avg         0.707      0.528      0.346
# Saved to /content/drive/MyDrive/ContinuousDeD/runs/medgridhard_discrete_15bins_50kframes/medgrid_disc_prec_rec_f1.png

# %%
# ── Boundary IoU ─────────────────────────────────────────────────────────────
# Boundary IoU (Cheng et al., 2021):
#   B_d(M) = M minus erosion(M, d)   — pixels inside mask within d of the edge
#   Boundary IoU = |B_d(GT) ∩ B_d(Pred)| / |B_d(GT) ∪ B_d(Pred)|
#
# d = 5 px ≈ 0.25 world-units at 200 px resolution

BOUNDARY_D = 5

def get_boundary(mask, d=BOUNDARY_D):
    if mask.sum() == 0:
        return np.zeros_like(mask, dtype=bool)
    eroded = binary_erosion(mask, iterations=d)
    return mask & ~eroded

def boundary_iou(gt_mask, pred_mask, d=BOUNDARY_D):
    bg = get_boundary(gt_mask, d)
    bp = get_boundary(pred_mask, d)
    inter = (bg & bp).sum()
    union = (bg | bp).sum()
    return float(inter) / (float(union) + 1e-8), bg, bp

gt_deadend_mask   = (gt_dense   == 'dead_end')
pred_deadend_mask = (pred_dense == 'dead_end')

biou_deadend, bg_d, bp_d = boundary_iou(gt_deadend_mask, pred_deadend_mask)

print(f"Boundary IoU (d={BOUNDARY_D} px = {BOUNDARY_D/DENSE_RES*SIZE:.2f} world-units):")
print(f"  Dead-end zone : {biou_deadend:.3f}")

# ── Visualise GT vs Pred maps + boundary comparison ──────────────────────────
CLASS_COLORS = {
    'dead_end':     np.array([231,  76,  60], dtype=np.uint8),   # red
    'not_dead_end': np.array([220, 220, 220], dtype=np.uint8),   # light grey
}

def labels_to_rgb(label_arr):
    rgb = np.zeros((*label_arr.shape, 3), dtype=np.uint8)
    for lbl, col in CLASS_COLORS.items():
        rgb[label_arr == lbl] = col
    return rgb

gt_rgb   = labels_to_rgb(gt_dense)
pred_rgb = labels_to_rgb(pred_dense)

agree_rgb = np.where(
    (gt_dense == pred_dense)[..., None],
    np.array([46, 204, 113], dtype=np.uint8),   # correct — green
    np.array([230, 126,  34], dtype=np.uint8),   # wrong   — orange
).astype(np.uint8)

fig, axes = plt.subplots(1, 4, figsize=(20, 5))

for ax, rgb, title in zip(
        axes[:3],
        [gt_rgb, pred_rgb, agree_rgb],
        ['Ground Truth', f'Agent Prediction ({n_bins}×{n_bins} bins)', 'Agreement (green=correct)']):
    ax.imshow(rgb, origin='lower', extent=[0, SIZE, 0, SIZE], aspect='equal')
    ax.set_title(title, fontsize=10)
    ax.set_xlabel('x'); ax.set_ylabel('y')
    for k in range(11):
        ax.axhline(k, color='white', lw=0.3, alpha=0.5)
        ax.axvline(k, color='white', lw=0.3, alpha=0.5)

ax = axes[3]
ax.imshow(gt_rgb, origin='lower', extent=[0, SIZE, 0, SIZE], aspect='equal', alpha=0.4)

def boundary_to_coords(bnd, xs, ys):
    rows, cols = np.where(bnd)
    return xs[cols], ys[rows]

bx_gt,   by_gt   = boundary_to_coords(bg_d, xs_dense, ys_dense)
bx_pred, by_pred = boundary_to_coords(bp_d, xs_dense, ys_dense)

ax.scatter(bx_gt,   by_gt,   s=1, c='#e74c3c', label='GT dead-end boundary',   linewidths=0)
ax.scatter(bx_pred, by_pred, s=1, c='#c0392b', marker='x', label='Pred dead-end boundary', linewidths=0.3)

ax.set_xlim(0, SIZE); ax.set_ylim(0, SIZE)
ax.set_title(f'Boundary IoU — Dead-end zone: {biou_deadend:.3f}', fontsize=10)
ax.set_xlabel('x'); ax.set_ylabel('y')
ax.legend(loc='upper right', fontsize=7, markerscale=5)

fig.suptitle(f'Region Detection — {DISC_RUN_NAME}  (source state {FIXED_STATE})', fontsize=12)
plt.tight_layout()
out_path = os.path.join(DISC_RUN_DIR, 'medgrid_disc_boundary_iou.png')
plt.savefig(out_path, dpi=150, bbox_inches='tight')
plt.show()
print('Saved to', out_path)
# Out:
# Boundary IoU (d=5 px = 0.25 world-units):
#   Dead-end zone : 0.141
# Saved to /content/drive/MyDrive/ContinuousDeD/runs/medgridhard_discrete_15bins_50kframes/medgrid_disc_boundary_iou.png
